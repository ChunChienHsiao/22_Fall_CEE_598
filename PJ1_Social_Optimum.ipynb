# %% [markdown]
# # Project 1 (Social Optimum)
#
# ***Chun-Chien Hsiao***
#
# As the leading modeler you are charged to **determine the user equilibrium (UE) flow distribution** across the arterial highway network of Sioux Falls, South Dakota. You are asked to **report link volumes and point out the bottlenecks**, corresponding to the most congested links of the highway network, based on an established $\frac{v}{c}$ standard, where $\frac{v}{c} > 0.90$. Based on your UE analysis you are tasked to **propose an effective congestion pricing scheme** to be considered by the metropolitan planning organization of the Sioux Falls area in South Dakota. In order to achieve this objective, the system optimum flow distribution needs to be estimated and the marginal-cost pricing link tolls need to be presented. As a modeler you are tasked to verify that the marginal-cost pricing scheme is a first- best tolling scheme. The network configuration in Sioux Falls, South Dakota, is presented in Figure 1.
#
# Data on the capacities $c_a$ and the free flow travel times $t_a^0$ of the network links are given in Table 1. Table 2 presents the origin-destination (OD) matrix for the Sioux Falls network. The link travel times (link performance functions) are given by the BPR function: $t_a(x) = t_a^0(1+0.15(\frac{x_a}{c_a})^4)$.

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize
from scipy import integrate
import math
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# # Frank-Wolfe Algorithm
#
# ### I. Network Properties

# %%
# link data
dflink = pd.read_excel('Data.xlsx', index_col=0, sheet_name=0)
dflink['ca'] = dflink['ca']*1000
dflink
# Out:
#              ta0(minutes)       ca  From  To
# Link Number
# 1                     3.6   6020.0     1   2
# 2                     2.4   9010.0     1   3
# 3                     3.6  12020.0     2   1
# 4                     3.0  15920.0     2   6
# 5                     2.4  46810.0     3   1
# ...                   ...      ...   ...  ..
# 72                    2.4  10000.0    23  22
# 73                    1.2  10160.0    23  24
# 74                    2.4  11380.0    24  13
# 75                    1.8   9770.0    24  21
# 76                    1.2  10160.0    24  23
#
# [76 rows x 4 columns]

# %%
# draw a network
G = nx.from_pandas_edgelist(dflink, source='From', target='To', edge_attr=('ta0(minutes)', 'ca'), create_using=nx.DiGraph)
G.add_node(1, loc=(1,8))
G.add_node(2, loc=(4,8))
G.add_node(3, loc=(1,7))
G.add_node(4, loc=(2,7))
G.add_node(5, loc=(3,7))
G.add_node(6, loc=(4,7))
G.add_node(7, loc=(5,6))
G.add_node(8, loc=(4,6))
G.add_node(9, loc=(3,6))
G.add_node(10, loc=(3,5))
G.add_node(11, loc=(2,5))
G.add_node(12, loc=(1,5))
G.add_node(13, loc=(1,1))
G.add_node(14, loc=(2,3))
G.add_node(15, loc=(3,3))
G.add_node(16, loc=(4,5))
G.add_node(17, loc=(4,4))
G.add_node(18, loc=(5,5))
G.add_node(19, loc=(4,3))
G.add_node(20, loc=(4,1))
G.add_node(21, loc=(3,1))
G.add_node(22, loc=(3,2))
G.add_node(23, loc=(2,2))
G.add_node(24, loc=(2,1))

# get the node and edge attribute
pos = nx.get_node_attributes(G, 'loc')
time = nx.get_edge_attributes(G, 'ta0(minutes)')
capacity = nx.get_edge_attributes(G, 'ca')
edgelist = list(G.edges())
nodelist = list(G.nodes())

# draw graph
# plt.figure(figsize=(6,8), dpi=100)
# nx.draw_networkx(G, pos, arrows=True, with_labels=True)
# plt.show()

# %%
# demand of each OD
dfnode = pd.read_excel('Data.xlsx', index_col=1, sheet_name=1, skiprows=[0])
dfnode = dfnode.drop(dfnode.columns[0], axis=1)
dfnode
# Out:
#        1     2     4     5    10    11    13    14    15    19    20    21  \
# 1      0  1320  1320  1320  1080  1100  1250   990   950   900   590   590
# 2   1320     0  1250  1300  1100  1120   900   950   940  1300   590   680
# 4   1320  1250     0  1320  1080  1070   950   900   840   800  1620   640
# 5   1320  1300  1320     0  1130   970   910   880   810   730   800   810
# 10  1080  1100  1080  1130     0  1330   900   990  1320  1170   950   900
# 11  1100  1120  1070   970  1330     0   940  1320  1110   950   740   610
# 13  1250   900   950   910   900   940     0   870   860   680   590   620
# 14   990   950   900   880   990  1320   870     0  1320  1130   950   870
# 15   950   940   840   810  1320  1110   860  1320     0  1320  1270  1140
# 19   900  1300   800   730  1170   950   680  1130  1320     0  1320  1110
# 20   590   590  1620   800   950   740   590   980  1270  1320     0  1320
# 21   590   680   640   810   900   610   620   870  1140  1110  1320     0
# 22   770   670   590   940   970  1100   670   900  1320  1100  1320  1320
# 24   740   590   800   590   590  1050  1320  1130   910   800   610  1320
#
#       22    24
# 1    770   740
# 2    670   590
# 4    590   800
# 5    940   590
# 10   970   590
# 11  1100  1050
# 13   670  1320
# 14   900  1130
# 15  1320   910
# 19  1100   800
# 20  1320   610
# 21  1320  1320
# 22     0  1130
# 24  1130     0

# %%
# Origin and Destination
noncentral = [3,6,7,8,9,12,16,17,18,23]
origins, destinations = nodelist, nodelist

for element in noncentral:
    if element in origins:
        origins.remove(element)
    elif element in destinations:
        destinations.remove(element)

OD = [[a,b] for a in origins for b in destinations]

# Demand(Dict)
demand = {a: {b: dfnode[a][b] for b in destinations} for a in origins}

# %% [markdown]
# ### Travel Time Function

# %%
def tij(t0,xa,ca):
    tij = t0*(1+0.75*(xa/ca)**4)
    return tij

def zij(t0,xa,ca):
    zij = t0*(xa+0.15*xa**5/ca**4)
    return zij

# %% [markdown]
# ### All-or-Nothing Algorithm

# %%
def all_nothing(timefeed):
    # Define a new graph with new feed time
    G_new = nx.DiGraph()
    G_new.add_weighted_edges_from((k,v, timefeed[(k,v)]) for k,v in edgelist)
    
    # Bellman-Ford Algorithm
    allpaths = dict(nx.all_pairs_bellman_ford_path(G_new, weight='weight'))
    
    # Clean all pairs path to OD pairs in Project 1
    for i in range(len(noncentral)):
        del allpaths[noncentral[i]]
    
    for i in range(len(origins)):
        for j in range(len(noncentral)):
            del allpaths[origins[i]][noncentral[j]]
    
    # Finding ya
    ya_iter = {(u,v): 0 for u,v in edgelist}
    
    for k in range(len(OD)):
        ODpath = allpaths[OD[k][0]][OD[k][1]]
        used_link = []
        
        if len(ODpath)>1:
            for j in range(len(ODpath)-1):
                B = []
                B.append(ODpath[j])
                B.append(ODpath[j+1])
                used_link.append(B)
        
        for i in range(len(used_link)):
            (used_link[i][0], used_link[i][1])
            ya_iter[(used_link[i][0], used_link[i][1])] += demand[OD[k][0]][OD[k][1]]
        
    return ya_iter

# %% [markdown]
# ### Bisection Algorithm

# %%
def bisection(x,y,edgelist,time,capacity):
    ya_iter = []
    xa_iter = []
    ya_iter = y
    xa_iter = x
    
    a = 0
    b = 1
    
    def fa(alpha):
        fa = 0
        for i in range(len(edgelist)):
            xa = xa_iter[edgelist[i]]
            ya = ya_iter[edgelist[i]]
            change = ya - xa
            time0 = time[edgelist[i]]
            ca = capacity[edgelist[i]]
            
            fa += time0*(xa_iter[edgelist[i]]+alpha*change)+0.15*time0/(ca**4)*(xa+alpha*change)**5
        return fa
    
    def dfa(alpha):
        dfa = 0
        for i in range(len(edgelist)):
            xa = xa_iter[edgelist[i]]
            ya = ya_iter[edgelist[i]]
            change = ya-xa
            time0 = time[edgelist[i]]
            ca = capacity[edgelist[i]]
            
            dfa += time0*change+0.75*time0/(ca**4)*change*(xa+alpha*change)**4
        return dfa
    
    m = (a+b)/2
    
    while (np.abs(a-b))>=10**(-10):
        if np.sign(dfa(m))<0:
            a = m
        else:
            b = m
        m = (a+b)/2
    return m

# %% [markdown]
# ### Initialization

# %%
time_int = time
#print(time_int)
xa = all_nothing(time_int)
#print(xa)

for (u,v) in edgelist:
    xa[(u,v)] = float(xa[(u,v)])

Zij = {(u,v): zij(time[(u,v)], xa[(u,v)], capacity[(u,v)]) for u,v in edgelist}
Z = sum(Zij.values())

print('Initialization:')
print('Objective Z = {:.4f}.'.format(Z))
# Out:
# Initialization:
# Objective Z = 1329277.9896.

# %% [markdown]
# ### Frank-Wolfe Iterations for SO

# %%
error = 100
tol = 10**(-4)
xa_old = xa
noi = 0

for u,v in edgelist:
    xa_old[(u,v)] = float(xa_old[(u,v)])
    
while error>tol:
    print('Iteration: {:.0f}'.format(noi+1))
    
    # Calcualte the new travel time
    newtime = {(u,v): tij(time[(u,v)], xa_old[(u,v)], capacity[(u,v)]) for u,v in edgelist}
    
    # All-or-Nothing Algorithm
    ya = all_nothing(newtime)
    
    for u,v in edgelist:
        ya[(u,v)] = float(ya[(u,v)])
    
    # Find Alpha
    alpha = bisection(xa_old, ya, edgelist, time, capacity)
    print('The step size of this iteration: {:.4f}'.format(alpha))
    
    # New Direction
    xa_new = {(u,v): xa_old[(u,v)]+alpha*(ya[(u,v)]-xa_old[(u,v)]) for u,v in edgelist}
    
    # Objective
    Zij = {(u,v): zij(time[(u,v)], xa_new[(u,v)], capacity[(u,v)]) for u,v in edgelist}
    Z = sum(Zij.values())
    print('The obejctive value of this iteration: {:.4f}'.format(Z))
    
    # Error
    eij = {(u,v): (xa_old[(u,v)]-xa_new[(u,v)])**2 for u,v in edgelist}
    error = np.sqrt(sum(eij.values()))/sum(xa_old.values())
    print('The error of this iteration: {:.5f}'.format(error))
    
    if error>=tol:
        print('The error is still too large, please keep going!\n')
    else:
        print('The error is within the tolerance, you\'re all set!\n')
    
    # Update Flow
    xa_old = xa_new
    for u,v in edgelist:
        xa_old[(u,v)] = float(xa_old[(u,v)])
    noi += 1
# Out:
# Iteration: 1
# The step size of this iteration: 0.2502
# The obejctive value of this iteration: 1289032.2157
# The error of this iteration: 0.02378
# The error is still too large, please keep going!
#
# Iteration: 2
# The step size of this iteration: 0.5323
# The obejctive value of this iteration: 1272714.7688
# The error of this iteration: 0.02025
# The error is still too large, please keep going!
#
# Iteration: 3
# The step size of this iteration: 0.2244
# The obejctive value of this iteration: 1268913.8325
# The error of this iteration: 0.01000
# The error is still too large, please keep going!
#
# Iteration: 4
# The step size of this iteration: 0.6025
# The obejctive value of this iteration: 1262928.6586
# The error of this iteration: 0.01441
# The error is still too large, please keep going!
#
# Iteration: 5
# The step size of this iteration: 0.1802
# The obejctive value of this iteration: 1260575.0215
# The error of this iteration: 0.00857
# The error is still too large, please keep going!
#
# Iteration: 6
# The step size of this iteration: 0.2659
# The obejctive value of this iteration: 1259308.0596
# The error of this iteration: 0.00607
# The error is still too large, please keep going!
#
# Iteration: 7
# The step size of this iteration: 0.2215
# The obejctive value of this iteration: 1258340.3405
# The error of this iteration: 0.00593
# The error is still too large, please keep going!
#
# Iteration: 8
# The step size of this iteration: 0.2666
# The obejctive value of this iteration: 1257531.1589
# The error of this iteration: 0.00499
# The error is still too large, please keep going!
#
# Iteration: 9
# The step size of this iteration: 0.1190
# The obejctive value of this iteration: 1257166.4458
# The error of this iteration: 0.00355
# The error is still too large, please keep going!
#
# Iteration: 10
# The step size of this iteration: 0.2423
# The obejctive value of this iteration: 1256814.8588
# The error of this iteration: 0.00415
# The error is still too large, please keep going!
#
# Iteration: 11
# The step size of this iteration: 0.1183
# The obejctive value of this iteration: 1256528.6098
# The error of this iteration: 0.00306
# The error is still too large, please keep going!
#
# Iteration: 12
# The step size of this iteration: 0.1285
# The obejctive value of this iteration: 1256380.6166
# The error of this iteration: 0.00205
# The error is still too large, please keep going!
#
# Iteration: 13
# The step size of this iteration: 0.1018
# The obejctive value of this iteration: 1256221.9528
# The error of this iteration: 0.00232
# The error is still too large, please keep going!
#
# Iteration: 14
# The step size of this iteration: 0.0890
# The obejctive value of this iteration: 1256131.5495
# The error of this iteration: 0.00165
# The error is still too large, please keep going!
#
# Iteration: 15
# The step size of this iteration: 0.0835
# The obejctive value of this iteration: 1256049.6167
# The error of this iteration: 0.00171
# The error is still too large, please keep going!
#
# Iteration: 16
# The step size of this iteration: 0.0972
# The obejctive value of this iteration: 1255967.0385
# The error of this iteration: 0.00180
# The error is still too large, please keep going!
#
# Iteration: 17
# The step size of this iteration: 0.0525
# The obejctive value of this iteration: 1255918.6576
# The error of this iteration: 0.00132
# The error is still too large, please keep going!
#
# Iteration: 18
# The step size of this iteration: 0.0774
# The obejctive value of this iteration: 1255867.3650
# The error of this iteration: 0.00123
# The error is still too large, please keep going!
#
# Iteration: 19
# The step size of this iteration: 0.0567
# The obejctive value of this iteration: 1255821.1028
# The error of this iteration: 0.00121
# The error is still too large, please keep going!
#
# Iteration: 20
# The step size of this iteration: 0.0875
# The obejctive value of this iteration: 1255768.4081
# The error of this iteration: 0.00157
# The error is still too large, please keep going!
#
# Iteration: 21
# The step size of this iteration: 0.0532
# The obejctive value of this iteration: 1255728.2153
# The error of this iteration: 0.00112
# The error is still too large, please keep going!
#
# Iteration: 22
# The step size of this iteration: 0.0604
# The obejctive value of this iteration: 1255698.5342
# The error of this iteration: 0.00093
# The error is still too large, please keep going!
#
# Iteration: 23
# The step size of this iteration: 0.0450
# The obejctive value of this iteration: 1255670.1162
# The error of this iteration: 0.00097
# The error is still too large, please keep going!
#
# Iteration: 24
# The step size of this iteration: 0.0642
# The obejctive value of this iteration: 1255640.1289
# The error of this iteration: 0.00093
# The error is still too large, please keep going!
#
# Iteration: 25
# The step size of this iteration: 0.0318
# The obejctive value of this iteration: 1255622.9453
# The error of this iteration: 0.00075
# The error is still too large, please keep going!
#
# Iteration: 26
# The step size of this iteration: 0.0517
# The obejctive value of this iteration: 1255603.8658
# The error of this iteration: 0.00091
# The error is still too large, please keep going!
#
# Iteration: 27
# The step size of this iteration: 0.0406
# The obejctive value of this iteration: 1255583.0089
# The error of this iteration: 0.00086
# The error is still too large, please keep going!
#
# Iteration: 28
# The step size of this iteration: 0.0606
# The obejctive value of this iteration: 1255560.0274
# The error of this iteration: 0.00091
# The error is still too large, please keep going!
#
# Iteration: 29
# The step size of this iteration: 0.0362
# The obejctive value of this iteration: 1255542.4116
# The error of this iteration: 0.00078
# The error is still too large, please keep going!
#
# Iteration: 30
# The step size of this iteration: 0.0492
# The obejctive value of this iteration: 1255525.9425
# The error of this iteration: 0.00086
# The error is still too large, please keep going!
#
# Iteration: 31
# The step size of this iteration: 0.0284
# The obejctive value of this iteration: 1255514.8286
# The error of this iteration: 0.00061
# The error is still too large, please keep going!
#
# Iteration: 32
# The step size of this iteration: 0.0404
# The obejctive value of this iteration: 1255501.7696
# The error of this iteration: 0.00062
# The error is still too large, please keep going!
#
# Iteration: 33
# The step size of this iteration: 0.0257
# The obejctive value of this iteration: 1255491.8171
# The error of this iteration: 0.00058
# The error is still too large, please keep going!
#
# Iteration: 34
# The step size of this iteration: 0.0331
# The obejctive value of this iteration: 1255482.9827
# The error of this iteration: 0.00056
# The error is still too large, please keep going!
#
# Iteration: 35
# The step size of this iteration: 0.0232
# The obejctive value of this iteration: 1255474.9144
# The error of this iteration: 0.00052
# The error is still too large, please keep going!
#
# Iteration: 36
# The step size of this iteration: 0.0371
# The obejctive value of this iteration: 1255465.5906
# The error of this iteration: 0.00058
# The error is still too large, please keep going!
#
# Iteration: 37
# The step size of this iteration: 0.0257
# The obejctive value of this iteration: 1255456.4625
# The error of this iteration: 0.00056
# The error is still too large, please keep going!
#
# Iteration: 38
# The step size of this iteration: 0.0353
# The obejctive value of this iteration: 1255448.1191
# The error of this iteration: 0.00055
# The error is still too large, please keep going!
#
# Iteration: 39
# The step size of this iteration: 0.0223
# The obejctive value of this iteration: 1255441.1707
# The error of this iteration: 0.00049
# The error is still too large, please keep going!
#
# Iteration: 40
# The step size of this iteration: 0.0307
# The obejctive value of this iteration: 1255433.8479
# The error of this iteration: 0.00054
# The error is still too large, please keep going!
#
# Iteration: 41
# The step size of this iteration: 0.0214
# The obejctive value of this iteration: 1255427.9498
# The error of this iteration: 0.00045
# The error is still too large, please keep going!
#
# Iteration: 42
# The step size of this iteration: 0.0303
# The obejctive value of this iteration: 1255420.9231
# The error of this iteration: 0.00045
# The error is still too large, please keep going!
#
# Iteration: 43
# The step size of this iteration: 0.0191
# The obejctive value of this iteration: 1255415.4619
# The error of this iteration: 0.00043
# The error is still too large, please keep going!
#
# Iteration: 44
# The step size of this iteration: 0.0321
# The obejctive value of this iteration: 1255408.7551
# The error of this iteration: 0.00056
# The error is still too large, please keep going!
#
# Iteration: 45
# The step size of this iteration: 0.0199
# The obejctive value of this iteration: 1255403.2564
# The error of this iteration: 0.00041
# The error is still too large, please keep going!
#
# Iteration: 46
# The step size of this iteration: 0.0221
# The obejctive value of this iteration: 1255398.9412
# The error of this iteration: 0.00039
# The error is still too large, please keep going!
#
# Iteration: 47
# The step size of this iteration: 0.0181
# The obejctive value of this iteration: 1255394.8706
# The error of this iteration: 0.00035
# The error is still too large, please keep going!
#
# Iteration: 48
# The step size of this iteration: 0.0310
# The obejctive value of this iteration: 1255388.6658
# The error of this iteration: 0.00047
# The error is still too large, please keep going!
#
# Iteration: 49
# The step size of this iteration: 0.0186
# The obejctive value of this iteration: 1255383.9076
# The error of this iteration: 0.00038
# The error is still too large, please keep going!
#
# Iteration: 50
# The step size of this iteration: 0.0201
# The obejctive value of this iteration: 1255380.4067
# The error of this iteration: 0.00036
# The error is still too large, please keep going!
#
# Iteration: 51
# The step size of this iteration: 0.0167
# The obejctive value of this iteration: 1255376.9395
# The error of this iteration: 0.00034
# The error is still too large, please keep going!
#
# Iteration: 52
# The step size of this iteration: 0.0266
# The obejctive value of this iteration: 1255372.3852
# The error of this iteration: 0.00040
# The error is still too large, please keep going!
#
# Iteration: 53
# The step size of this iteration: 0.0136
# The obejctive value of this iteration: 1255369.3095
# The error of this iteration: 0.00034
# The error is still too large, please keep going!
#
# Iteration: 54
# The step size of this iteration: 0.0317
# The obejctive value of this iteration: 1255364.6296
# The error of this iteration: 0.00053
# The error is still too large, please keep going!
#
# Iteration: 55
# The step size of this iteration: 0.0180
# The obejctive value of this iteration: 1255360.6069
# The error of this iteration: 0.00035
# The error is still too large, please keep going!
#
# Iteration: 56
# The step size of this iteration: 0.0265
# The obejctive value of this iteration: 1255356.0707
# The error of this iteration: 0.00040
# The error is still too large, please keep going!
#
# Iteration: 57
# The step size of this iteration: 0.0179
# The obejctive value of this iteration: 1255352.0243
# The error of this iteration: 0.00040
# The error is still too large, please keep going!
#
# Iteration: 58
# The step size of this iteration: 0.0197
# The obejctive value of this iteration: 1255349.1010
# The error of this iteration: 0.00029
# The error is still too large, please keep going!
#
# Iteration: 59
# The step size of this iteration: 0.0131
# The obejctive value of this iteration: 1255346.4802
# The error of this iteration: 0.00030
# The error is still too large, please keep going!
#
# Iteration: 60
# The step size of this iteration: 0.0179
# The obejctive value of this iteration: 1255344.0050
# The error of this iteration: 0.00027
# The error is still too large, please keep going!
#
# Iteration: 61
# The step size of this iteration: 0.0123
# The obejctive value of this iteration: 1255341.7556
# The error of this iteration: 0.00027
# The error is still too large, please keep going!
#
# Iteration: 62
# The step size of this iteration: 0.0169
# The obejctive value of this iteration: 1255339.4827
# The error of this iteration: 0.00029
# The error is still too large, please keep going!
#
# Iteration: 63
# The step size of this iteration: 0.0120
# The obejctive value of this iteration: 1255337.3564
# The error of this iteration: 0.00027
# The error is still too large, please keep going!
#
# Iteration: 64
# The step size of this iteration: 0.0207
# The obejctive value of this iteration: 1255334.6663
# The error of this iteration: 0.00031
# The error is still too large, please keep going!
#
# Iteration: 65
# The step size of this iteration: 0.0136
# The obejctive value of this iteration: 1255332.1130
# The error of this iteration: 0.00030
# The error is still too large, please keep going!
#
# Iteration: 66
# The step size of this iteration: 0.0184
# The obejctive value of this iteration: 1255329.7630
# The error of this iteration: 0.00026
# The error is still too large, please keep going!
#
# Iteration: 67
# The step size of this iteration: 0.0128
# The obejctive value of this iteration: 1255327.6232
# The error of this iteration: 0.00027
# The error is still too large, please keep going!
#
# Iteration: 68
# The step size of this iteration: 0.0169
# The obejctive value of this iteration: 1255325.4393
# The error of this iteration: 0.00030
# The error is still too large, please keep going!
#
# Iteration: 69
# The step size of this iteration: 0.0120
# The obejctive value of this iteration: 1255323.4841
# The error of this iteration: 0.00026
# The error is still too large, please keep going!
#
# Iteration: 70
# The step size of this iteration: 0.0178
# The obejctive value of this iteration: 1255321.3652
# The error of this iteration: 0.00027
# The error is still too large, please keep going!
#
# Iteration: 71
# The step size of this iteration: 0.0115
# The obejctive value of this iteration: 1255319.5200
# The error of this iteration: 0.00026
# The error is still too large, please keep going!
#
# Iteration: 72
# The step size of this iteration: 0.0167
# The obejctive value of this iteration: 1255317.5776
# The error of this iteration: 0.00026
# The error is still too large, please keep going!
#
# Iteration: 73
# The step size of this iteration: 0.0104
# The obejctive value of this iteration: 1255315.9694
# The error of this iteration: 0.00023
# The error is still too large, please keep going!
#
# Iteration: 74
# The step size of this iteration: 0.0180
# The obejctive value of this iteration: 1255314.0023
# The error of this iteration: 0.00025
# The error is still too large, please keep going!
#
# Iteration: 75
# The step size of this iteration: 0.0115
# The obejctive value of this iteration: 1255312.1182
# The error of this iteration: 0.00025
# The error is still too large, please keep going!
#
# Iteration: 76
# The step size of this iteration: 0.0141
# The obejctive value of this iteration: 1255310.6253
# The error of this iteration: 0.00024
# The error is still too large, please keep going!
#
# Iteration: 77
# The step size of this iteration: 0.0112
# The obejctive value of this iteration: 1255309.0245
# The error of this iteration: 0.00024
# The error is still too large, please keep going!
#
# Iteration: 78
# The step size of this iteration: 0.0172
# The obejctive value of this iteration: 1255307.1316
# The error of this iteration: 0.00026
# The error is still too large, please keep going!
#
# Iteration: 79
# The step size of this iteration: 0.0110
# The obejctive value of this iteration: 1255305.4799
# The error of this iteration: 0.00024
# The error is still too large, please keep going!
#
# Iteration: 80
# The step size of this iteration: 0.0151
# The obejctive value of this iteration: 1255303.9188
# The error of this iteration: 0.00026
# The error is still too large, please keep going!
#
# Iteration: 81
# The step size of this iteration: 0.0106
# The obejctive value of this iteration: 1255302.5507
# The error of this iteration: 0.00022
# The error is still too large, please keep going!
#
# Iteration: 82
# The step size of this iteration: 0.0160
# The obejctive value of this iteration: 1255300.6588
# The error of this iteration: 0.00023
# The error is still too large, please keep going!
#
# Iteration: 83
# The step size of this iteration: 0.0104
# The obejctive value of this iteration: 1255299.3165
# The error of this iteration: 0.00021
# The error is still too large, please keep going!
#
# Iteration: 84
# The step size of this iteration: 0.0132
# The obejctive value of this iteration: 1255298.0085
# The error of this iteration: 0.00020
# The error is still too large, please keep going!
#
# Iteration: 85
# The step size of this iteration: 0.0074
# The obejctive value of this iteration: 1255297.0303
# The error of this iteration: 0.00019
# The error is still too large, please keep going!
#
# Iteration: 86
# The step size of this iteration: 0.0137
# The obejctive value of this iteration: 1255295.7431
# The error of this iteration: 0.00027
# The error is still too large, please keep going!
#
# Iteration: 87
# The step size of this iteration: 0.0100
# The obejctive value of this iteration: 1255294.5186
# The error of this iteration: 0.00019
# The error is still too large, please keep going!
#
# Iteration: 88
# The step size of this iteration: 0.0140
# The obejctive value of this iteration: 1255293.0480
# The error of this iteration: 0.00021
# The error is still too large, please keep going!
#
# Iteration: 89
# The step size of this iteration: 0.0091
# The obejctive value of this iteration: 1255291.9411
# The error of this iteration: 0.00019
# The error is still too large, please keep going!
#
# Iteration: 90
# The step size of this iteration: 0.0133
# The obejctive value of this iteration: 1255290.6672
# The error of this iteration: 0.00019
# The error is still too large, please keep going!
#
# Iteration: 91
# The step size of this iteration: 0.0076
# The obejctive value of this iteration: 1255289.7122
# The error of this iteration: 0.00018
# The error is still too large, please keep going!
#
# Iteration: 92
# The step size of this iteration: 0.0134
# The obejctive value of this iteration: 1255288.5868
# The error of this iteration: 0.00020
# The error is still too large, please keep going!
#
# Iteration: 93
# The step size of this iteration: 0.0102
# The obejctive value of this iteration: 1255287.3056
# The error of this iteration: 0.00021
# The error is still too large, please keep going!
#
# Iteration: 94
# The step size of this iteration: 0.0106
# The obejctive value of this iteration: 1255286.3163
# The error of this iteration: 0.00018
# The error is still too large, please keep going!
#
# Iteration: 95
# The step size of this iteration: 0.0075
# The obejctive value of this iteration: 1255285.5520
# The error of this iteration: 0.00015
# The error is still too large, please keep going!
#
# Iteration: 96
# The step size of this iteration: 0.0147
# The obejctive value of this iteration: 1255284.2699
# The error of this iteration: 0.00021
# The error is still too large, please keep going!
#
# Iteration: 97
# The step size of this iteration: 0.0097
# The obejctive value of this iteration: 1255283.0678
# The error of this iteration: 0.00020
# The error is still too large, please keep going!
#
# Iteration: 98
# The step size of this iteration: 0.0113
# The obejctive value of this iteration: 1255282.1046
# The error of this iteration: 0.00019
# The error is still too large, please keep going!
#
# Iteration: 99
# The step size of this iteration: 0.0067
# The obejctive value of this iteration: 1255281.3589
# The error of this iteration: 0.00016
# The error is still too large, please keep going!
#
# Iteration: 100
# The step size of this iteration: 0.0142
# The obejctive value of this iteration: 1255280.2723
# The error of this iteration: 0.00021
# The error is still too large, please keep going!
#
# Iteration: 101
# The step size of this iteration: 0.0083
# The obejctive value of this iteration: 1255279.3466
# The error of this iteration: 0.00017
# The error is still too large, please keep going!
#
# Iteration: 102
# The step size of this iteration: 0.0113
# The obejctive value of this iteration: 1255278.3705
# The error of this iteration: 0.00019
# The error is still too large, please keep going!
#
# Iteration: 103
# The step size of this iteration: 0.0075
# The obejctive value of this iteration: 1255277.5452
# The error of this iteration: 0.00017
# The error is still too large, please keep going!
#
# Iteration: 104
# The step size of this iteration: 0.0122
# The obejctive value of this iteration: 1255276.5632
# The error of this iteration: 0.00019
# The error is still too large, please keep going!
#
# Iteration: 105
# The step size of this iteration: 0.0081
# The obejctive value of this iteration: 1255275.6667
# The error of this iteration: 0.00018
# The error is still too large, please keep going!
#
# Iteration: 106
# The step size of this iteration: 0.0113
# The obejctive value of this iteration: 1255274.8124
# The error of this iteration: 0.00017
# The error is still too large, please keep going!
#
# Iteration: 107
# The step size of this iteration: 0.0076
# The obejctive value of this iteration: 1255274.0105
# The error of this iteration: 0.00017
# The error is still too large, please keep going!
#
# Iteration: 108
# The step size of this iteration: 0.0096
# The obejctive value of this iteration: 1255273.2768
# The error of this iteration: 0.00017
# The error is still too large, please keep going!
#
# Iteration: 109
# The step size of this iteration: 0.0077
# The obejctive value of this iteration: 1255272.5201
# The error of this iteration: 0.00016
# The error is still too large, please keep going!
#
# Iteration: 110
# The step size of this iteration: 0.0106
# The obejctive value of this iteration: 1255271.6750
# The error of this iteration: 0.00016
# The error is still too large, please keep going!
#
# Iteration: 111
# The step size of this iteration: 0.0075
# The obejctive value of this iteration: 1255270.9247
# The error of this iteration: 0.00015
# The error is still too large, please keep going!
#
# Iteration: 112
# The step size of this iteration: 0.0107
# The obejctive value of this iteration: 1255270.1203
# The error of this iteration: 0.00017
# The error is still too large, please keep going!
#
# Iteration: 113
# The step size of this iteration: 0.0067
# The obejctive value of this iteration: 1255269.5056
# The error of this iteration: 0.00014
# The error is still too large, please keep going!
#
# Iteration: 114
# The step size of this iteration: 0.0097
# The obejctive value of this iteration: 1255268.7639
# The error of this iteration: 0.00017
# The error is still too large, please keep going!
#
# Iteration: 115
# The step size of this iteration: 0.0076
# The obejctive value of this iteration: 1255268.0582
# The error of this iteration: 0.00015
# The error is still too large, please keep going!
#
# Iteration: 116
# The step size of this iteration: 0.0101
# The obejctive value of this iteration: 1255267.2943
# The error of this iteration: 0.00015
# The error is still too large, please keep going!
#
# Iteration: 117
# The step size of this iteration: 0.0052
# The obejctive value of this iteration: 1255266.8121
# The error of this iteration: 0.00013
# The error is still too large, please keep going!
#
# Iteration: 118
# The step size of this iteration: 0.0127
# The obejctive value of this iteration: 1255265.9954
# The error of this iteration: 0.00018
# The error is still too large, please keep going!
#
# Iteration: 119
# The step size of this iteration: 0.0077
# The obejctive value of this iteration: 1255265.1934
# The error of this iteration: 0.00017
# The error is still too large, please keep going!
#
# Iteration: 120
# The step size of this iteration: 0.0083
# The obejctive value of this iteration: 1255264.6330
# The error of this iteration: 0.00014
# The error is still too large, please keep going!
#
# Iteration: 121
# The step size of this iteration: 0.0067
# The obejctive value of this iteration: 1255264.0952
# The error of this iteration: 0.00013
# The error is still too large, please keep going!
#
# Iteration: 122
# The step size of this iteration: 0.0067
# The obejctive value of this iteration: 1255263.5858
# The error of this iteration: 0.00013
# The error is still too large, please keep going!
#
# Iteration: 123
# The step size of this iteration: 0.0051
# The obejctive value of this iteration: 1255263.2296
# The error of this iteration: 0.00011
# The error is still too large, please keep going!
#
# Iteration: 124
# The step size of this iteration: 0.0087
# The obejctive value of this iteration: 1255262.6561
# The error of this iteration: 0.00014
# The error is still too large, please keep going!
#
# Iteration: 125
# The step size of this iteration: 0.0060
# The obejctive value of this iteration: 1255262.1277
# The error of this iteration: 0.00013
# The error is still too large, please keep going!
#
# Iteration: 126
# The step size of this iteration: 0.0122
# The obejctive value of this iteration: 1255261.3468
# The error of this iteration: 0.00018
# The error is still too large, please keep going!
#
# Iteration: 127
# The step size of this iteration: 0.0068
# The obejctive value of this iteration: 1255260.6992
# The error of this iteration: 0.00015
# The error is still too large, please keep going!
#
# Iteration: 128
# The step size of this iteration: 0.0082
# The obejctive value of this iteration: 1255260.1635
# The error of this iteration: 0.00014
# The error is still too large, please keep going!
#
# Iteration: 129
# The step size of this iteration: 0.0063
# The obejctive value of this iteration: 1255259.6656
# The error of this iteration: 0.00013
# The error is still too large, please keep going!
#
# Iteration: 130
# The step size of this iteration: 0.0089
# The obejctive value of this iteration: 1255259.0418
# The error of this iteration: 0.00014
# The error is still too large, please keep going!
#
# Iteration: 131
# The step size of this iteration: 0.0059
# The obejctive value of this iteration: 1255258.5596
# The error of this iteration: 0.00012
# The error is still too large, please keep going!
#
# Iteration: 132
# The step size of this iteration: 0.0109
# The obejctive value of this iteration: 1255257.8573
# The error of this iteration: 0.00016
# The error is still too large, please keep going!
#
# Iteration: 133
# The step size of this iteration: 0.0056
# The obejctive value of this iteration: 1255257.3320
# The error of this iteration: 0.00014
# The error is still too large, please keep going!
#
# Iteration: 134
# The step size of this iteration: 0.0064
# The obejctive value of this iteration: 1255256.9584
# The error of this iteration: 0.00011
# The error is still too large, please keep going!
#
# Iteration: 135
# The step size of this iteration: 0.0060
# The obejctive value of this iteration: 1255256.5226
# The error of this iteration: 0.00013
# The error is still too large, please keep going!
#
# Iteration: 136
# The step size of this iteration: 0.0090
# The obejctive value of this iteration: 1255255.9185
# The error of this iteration: 0.00015
# The error is still too large, please keep going!
#
# Iteration: 137
# The step size of this iteration: 0.0065
# The obejctive value of this iteration: 1255255.4137
# The error of this iteration: 0.00013
# The error is still too large, please keep going!
#
# Iteration: 138
# The step size of this iteration: 0.0094
# The obejctive value of this iteration: 1255254.8223
# The error of this iteration: 0.00014
# The error is still too large, please keep going!
#
# Iteration: 139
# The step size of this iteration: 0.0061
# The obejctive value of this iteration: 1255254.3282
# The error of this iteration: 0.00013
# The error is still too large, please keep going!
#
# Iteration: 140
# The step size of this iteration: 0.0077
# The obejctive value of this iteration: 1255253.8893
# The error of this iteration: 0.00011
# The error is still too large, please keep going!
#
# Iteration: 141
# The step size of this iteration: 0.0055
# The obejctive value of this iteration: 1255253.4660
# The error of this iteration: 0.00011
# The error is still too large, please keep going!
#
# Iteration: 142
# The step size of this iteration: 0.0098
# The obejctive value of this iteration: 1255252.9064
# The error of this iteration: 0.00015
# The error is still too large, please keep going!
#
# Iteration: 143
# The step size of this iteration: 0.0051
# The obejctive value of this iteration: 1255252.4791
# The error of this iteration: 0.00012
# The error is still too large, please keep going!
#
# Iteration: 144
# The step size of this iteration: 0.0076
# The obejctive value of this iteration: 1255252.0795
# The error of this iteration: 0.00013
# The error is still too large, please keep going!
#
# Iteration: 145
# The step size of this iteration: 0.0063
# The obejctive value of this iteration: 1255251.6033
# The error of this iteration: 0.00012
# The error is still too large, please keep going!
#
# Iteration: 146
# The step size of this iteration: 0.0082
# The obejctive value of this iteration: 1255251.1110
# The error of this iteration: 0.00012
# The error is still too large, please keep going!
#
# Iteration: 147
# The step size of this iteration: 0.0053
# The obejctive value of this iteration: 1255250.7288
# The error of this iteration: 0.00011
# The error is still too large, please keep going!
#
# Iteration: 148
# The step size of this iteration: 0.0094
# The obejctive value of this iteration: 1255250.1888
# The error of this iteration: 0.00014
# The error is still too large, please keep going!
#
# Iteration: 149
# The step size of this iteration: 0.0056
# The obejctive value of this iteration: 1255249.7489
# The error of this iteration: 0.00012
# The error is still too large, please keep going!
#
# Iteration: 150
# The step size of this iteration: 0.0092
# The obejctive value of this iteration: 1255249.2289
# The error of this iteration: 0.00016
# The error is still too large, please keep going!
#
# Iteration: 151
# The step size of this iteration: 0.0049
# The obejctive value of this iteration: 1255248.8260
# The error of this iteration: 0.00011
# The error is still too large, please keep going!
#
# Iteration: 152
# The step size of this iteration: 0.0068
# The obejctive value of this iteration: 1255248.4676
# The error of this iteration: 0.00011
# The error is still too large, please keep going!
#
# Iteration: 153
# The step size of this iteration: 0.0056
# The obejctive value of this iteration: 1255248.1247
# The error of this iteration: 0.00010
# The error is still too large, please keep going!
#
# Iteration: 154
# The step size of this iteration: 0.0086
# The obejctive value of this iteration: 1255247.5672
# The error of this iteration: 0.00015
# The error is still too large, please keep going!
#
# Iteration: 155
# The step size of this iteration: 0.0051
# The obejctive value of this iteration: 1255247.2150
# The error of this iteration: 0.00010
# The error is still too large, please keep going!
#
# Iteration: 156
# The step size of this iteration: 0.0080
# The obejctive value of this iteration: 1255246.7961
# The error of this iteration: 0.00012
# The error is still too large, please keep going!
#
# Iteration: 157
# The step size of this iteration: 0.0052
# The obejctive value of this iteration: 1255246.4196
# The error of this iteration: 0.00011
# The error is still too large, please keep going!
#
# Iteration: 158
# The step size of this iteration: 0.0064
# The obejctive value of this iteration: 1255246.0990
# The error of this iteration: 0.00011
# The error is still too large, please keep going!
#
# Iteration: 159
# The step size of this iteration: 0.0054
# The obejctive value of this iteration: 1255245.7502
# The error of this iteration: 0.00011
# The error is still too large, please keep going!
#
# Iteration: 160
# The step size of this iteration: 0.0091
# The obejctive value of this iteration: 1255245.2655
# The error of this iteration: 0.00012
# The error is still too large, please keep going!
#
# Iteration: 161
# The step size of this iteration: 0.0042
# The obejctive value of this iteration: 1255244.9588
# The error of this iteration: 0.00010
# The error is still too large, please keep going!
#
# Iteration: 162
# The step size of this iteration: 0.0064
# The obejctive value of this iteration: 1255244.6771
# The error of this iteration: 0.00010
# The error is within the tolerance, you're all set!

# %%
def tsij(t0, xa, ca):
    tsij = t0*(1+0.15*(xa/ca)**4)*xa
    return tsij

so_travel_time = {(u,v): tsij(time[(u,v)], xa_new[(u,v)], capacity[(u,v)]) for (u,v) in edgelist}
SO_travel_time = sum(so_travel_time.values())

print('Final Outcome:')
print('Objetive: {:.5f}'.format(Z))
print('Total Travel Time: {:.5f}'.format(SO_travel_time))
print('Eventual Error: {:.10f}'.format(error))
print('Number of Iterations: {:.0f}'.format(noi))
# Out:
# Final Outcome:
# Objetive: 1255244.67706
# Total Travel Time: 1255244.67706
# Eventual Error: 0.0000978502
# Number of Iterations: 162

# %%
SO_DataFrame = pd.DataFrame.from_dict(xa_new, orient='index', columns=['SO Flow'])
SO_DataFrame['Capacity'] = capacity.values()
SO_DataFrame['Time0'] = time.values()
SO_DataFrame['SO Travel Time'] = SO_DataFrame['Time0']*(1+0.15*(SO_DataFrame['SO Flow']/SO_DataFrame['Capacity'])**4)
SO_DataFrame['Toll'] = SO_DataFrame['Time0']*0.6*(SO_DataFrame['SO Flow']/SO_DataFrame['Capacity'])**4
SO_DataFrame['V/C'] = SO_DataFrame['SO Flow']/SO_DataFrame['Capacity']
SO_DataFrame = SO_DataFrame[['Time0', 'Capacity', 'SO Flow', 'SO Travel Time', 'Toll', 'V/C']]
SO_DataFrame
# Out:
#           Time0  Capacity       SO Flow  SO Travel Time      Toll       V/C
# (1, 2)      3.6    6020.0   5513.897622        3.980052  1.520206  0.915930
# (1, 3)      2.4    9010.0  10387.786392        3.036056  2.544224  1.152917
# (2, 1)      3.6   12020.0   3091.371262        3.602363  0.009450  0.257186
# (2, 6)      3.0   15920.0  12602.213608        3.176696  0.706785  0.791596
# (3, 1)      2.4   46810.0  12810.312752        2.402019  0.008077  0.273666
# ...         ...       ...           ...             ...       ...       ...
# (20, 21)    3.6   10120.0   6116.014982        3.672035  0.288142  0.604349
# (20, 22)    3.0   10150.0   4217.421801        3.013413  0.053653  0.415510
# (21, 20)    3.6   10120.0   5755.951014        3.656512  0.226048  0.568770
# (21, 22)    1.2   10460.0   6958.760266        1.235259  0.141037  0.665273
# (21, 24)    1.8    9770.0   8821.657664        1.979468  0.717871  0.902933
#
# [76 rows x 6 columns]

# %%
Bottleneck = SO_DataFrame[(SO_DataFrame['V/C']>=0.9)]
Bottleneck
# Out:
#           Time0  Capacity       SO Flow  SO Travel Time      Toll       V/C
# (1, 2)      3.6    6020.0   5513.897622        3.980052  1.520206  0.915930
# (1, 3)      2.4    9010.0  10387.786392        3.036056  2.544224  1.152917
# (6, 2)      3.0    9920.0  10179.687248        3.499003  1.996014  1.026178
# (11, 14)    2.4    9750.0   8899.783551        2.649920  0.999682  0.912798
# (8, 6)      1.2    9800.0   9207.670392        1.340271  0.561083  0.939558
# (14, 11)    2.4    9750.0   8941.773915        2.654671  1.018682  0.917105
# (13, 24)    2.4   10180.0  10325.595291        2.781041  1.524164  1.014302
# (24, 13)    2.4   11380.0  10661.441537        2.677330  1.109321  0.936858
# (21, 24)    1.8    9770.0   8821.657664        1.979468  0.717871  0.902933
